# %% [markdown]
# # Problem Statement:
#
# ### The goal of this project is to give people an estimate of how much they need based on their individual health situation.

# %% [markdown]
# # About Dataset
#
# ## Context
#
# ### The insurance.csv dataset contains 1338 observations (rows) and 7 features (columns). The dataset contains 4 numerical features (age, bmi, children and expenses) and 3 nominal features (sex, smoker and region) that were converted into factors with numerical value designated for each level.
#
# ## Acknowledgements
#
# ### Insurance.csv file is obtained from the Machine Learning course website (Spring 2017) from Professor Eric Suess at http://www.sci.csueastbay.edu/~esuess/stat6620/#week-6.

# %% [markdown]
# ###  1. Get the Data

# %%
import pandas as pd
import opendatasets as od
import warnings
warnings.filterwarnings('ignore')

# %%
od.download("https://www.kaggle.com/datasets/noordeen/insurance-premium-prediction")
# Out:
# Skipping, found downloaded files in ".\insurance-premium-prediction" (use force=True to force download)

# %%
data = pd.read_csv("insurance-premium-prediction/insurance.csv")

# %%
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
data.groupby('sex').count()
# Out:
#         age  bmi  children  smoker  region  expenses
# sex
# female  662  662       662     662     662       662
# male    676  676       676     676     676       676

# %%
# Preprocessing

import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
data.groupby('sex')['expenses'].count().plot.bar();

# %% [markdown]
# ### Labelized

# %%
le=LabelEncoder()

# %%
cat_col=data.select_dtypes(exclude=['int','float']).columns

# %%
cat_col
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
data[cat_col]=data[cat_col].apply(lambda x : le.fit_transform(x))

# %%
data[cat_col]
# Out:
#       sex  smoker  region
# 0       0       1       3
# 1       1       0       2
# 2       1       0       2
# 3       1       0       1
# 4       1       0       1
# ...   ...     ...     ...
# 1333    1       0       1
# 1334    0       0       0
# 1335    0       0       2
# 1336    0       0       3
# 1337    0       1       1
#
# [1338 rows x 3 columns]

# %%
data
# Out:
#       age  sex   bmi  children  smoker  region  expenses
# 0      19    0  27.9         0       1       3  16884.92
# 1      18    1  33.8         1       0       2   1725.55
# 2      28    1  33.0         3       0       2   4449.46
# 3      33    1  22.7         0       0       1  21984.47
# 4      32    1  28.9         0       0       1   3866.86
# ...   ...  ...   ...       ...     ...     ...       ...
# 1333   50    1  31.0         3       0       1  10600.55
# 1334   18    0  31.9         0       0       0   2205.98
# 1335   18    0  36.9         0       0       2   1629.83
# 1336   21    0  25.8         0       0       3   2007.95
# 1337   61    0  29.1         0       1       1  29141.36
#
# [1338 rows x 7 columns]

# %%
sns.kdeplot(data['expenses']);

# %%
sns.kdeplot(data['age']);

# %%
plt.figure(figsize=(12,10))
sns.countplot(data['sex']);

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(y=data['age'],x=data['expenses'],hue=data['sex'])
plt.show()

# %%
data.corr()
# Out:
#                age       sex       bmi  children    smoker    region  expenses
# age       1.000000 -0.020856  0.109341  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046380  0.017163  0.076185  0.004588  0.057292
# bmi       0.109341  0.046380  1.000000  0.012645  0.003968  0.157439  0.198576
# children  0.042469  0.017163  0.012645  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003968  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157439  0.016569 -0.002181  1.000000 -0.006208
# expenses  0.299008  0.057292  0.198576  0.067998  0.787251 -0.006208  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),annot=True,cmap='viridis')
plt.show()

# %%
# drop feature region  as it has negative co-relation with expenses
data.drop(columns="region",inplace=True)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),annot=True,cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(data['expenses'],shade=True);
plt.axvline(data['expenses'].mean(),color='red',linewidth=2)
plt.axvline(data['expenses'].median(),color='green',linewidth=2)
plt.show()

# %%
plt.figure(figsize=(35,35))
sns.pairplot(data,hue='sex', size=4)
plt.show()

# %%
data.groupby(by='sex').corr()
# Out:
#                    age       bmi  children    smoker  expenses
# sex
# 0   age       1.000000  0.097280  0.078500 -0.029199  0.324575
#     bmi       0.097280  1.000000  0.022099 -0.058053  0.161715
#     children  0.078500  0.022099  1.000000 -0.025144  0.058492
#     smoker   -0.029199 -0.058053 -0.025144  1.000000  0.746695
#     expenses  0.324575  0.161715  0.058492  0.746695  1.000000
# 1   age       1.000000  0.123162  0.008690 -0.018589  0.282369
#     bmi       0.123162  1.000000  0.002211  0.050820  0.226037
#     children  0.008690  0.002211  1.000000  0.033369  0.074496
#     smoker   -0.018589  0.050820  0.033369  1.000000  0.816579
#     expenses  0.282369  0.226037  0.074496  0.816579  1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.groupby(by='sex').corr(),annot=True,cmap='viridis')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns='expenses')
y=data['expenses']
num_col = ['age', 'bmi', 'children']

# %%
X
# Out:
#       age  sex   bmi  children  smoker
# 0      19    0  27.9         0       1
# 1      18    1  33.8         1       0
# 2      28    1  33.0         3       0
# 3      33    1  22.7         0       0
# 4      32    1  28.9         0       0
# ...   ...  ...   ...       ...     ...
# 1333   50    1  31.0         3       0
# 1334   18    0  31.9         0       0
# 1335   18    0  36.9         0       0
# 1336   21    0  25.8         0       0
# 1337   61    0  29.1         0       1
#
# [1338 rows x 5 columns]

# %% [markdown]
# ## Scalized

# %%
sc=StandardScaler()
X[num_col]=sc.fit_transform(X[num_col])

# %%
X
# Out:
#            age  sex       bmi  children  smoker
# 0    -1.438764    0 -0.453646 -0.908614       1
# 1    -1.509965    1  0.514186 -0.078767       0
# 2    -0.797954    1  0.382954  1.580926       0
# 3    -0.441948    1 -1.306650 -0.908614       0
# 4    -0.513149    1 -0.289606 -0.908614       0
# ...        ...  ...       ...       ...     ...
# 1333  0.768473    1  0.054876  1.580926       0
# 1334 -1.509965    0  0.202511 -0.908614       0
# 1335 -1.509965    0  1.022707 -0.908614       0
# 1336 -1.296362    0 -0.798128 -0.908614       0
# 1337  1.551686    0 -0.256799 -0.908614       1
#
# [1338 rows x 5 columns]

# %% [markdown]
# ## Spliting the X & y

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %% [markdown]
# ## HyperTuning model and param

# %%
model_parameter ={

"Linear_Regression" :{
                        "model" : LinearRegression(),
                        "param" : {}
                    },

"Decision_Tree_Regressor" :{
                        "model" : DecisionTreeRegressor(),
                        "param" : {
                                   'splitter' : ["best"],
                                   'ccp_alpha':[0.1,0.0,0.3]
                                  }
                            },

"SVR" : {
                        "model" : SVR(),
                        "param" : {}
       },

"KNeighbors_Classifier_Regressor" : {
                        "model" : KNeighborsRegressor(),
                        "param" : {'n_neighbors' : [4,5,6],
                                  'weights' : ['uniform', 'distance']
                                  }
},
                       

"Random_Forest_Regressor" :{
                    "model" : RandomForestRegressor(),
                    "param" : {'criterion' : ["squared_error", "absolute_error"],
                              'n_estimators':[100,85,90]
                              }
                      },
 "Bagging_Regressor" :{
                    "model" : BaggingRegressor(base_estimator=SVR(),random_state=0),
                    "param" : {'n_estimators':[10,100]}
                      },
    


 "AdaBoost_Regressor" :{
                    "model" : AdaBoostRegressor(),
                    "param" : {}
                      },

"Gradient_Boosting_Regressor" :{
                    "model" : GradientBoostingRegressor(),
                    "param" : {}
                      },

"XGB_Regressor" :{
                    "model" : XGBRegressor(),
                    "param" : {}
                      },
}

# %%
Report = []
for model_name ,model_param in model_parameter.items():
    gs = GridSearchCV(model_param['model'],model_param['param'],cv = 5,return_train_score=False)
    gs.fit(X_train,y_train)
    Report.append({'Model': model_name,
                 'Best_Score' : gs.best_score_,
                 'Best_Parameter' : gs.best_params_})

Model_Report = pd.DataFrame(Report,columns=['Model','Best_Score','Best_Parameter'])

# %%
Model_Report.sort_values(by='Best_Score',ascending=False)
# Out:
#                              Model  Best_Score  \
# 7      Gradient_Boosting_Regressor    0.862363
# 4          Random_Forest_Regressor    0.841580
# 6               AdaBoost_Regressor    0.820129
# 8                    XGB_Regressor    0.807564
# 3  KNeighbors_Classifier_Regressor    0.777301
# 0                Linear_Regression    0.762881
# 1          Decision_Tree_Regressor    0.741145
# 2                              SVR   -0.113797
# 5                Bagging_Regressor   -0.114533
#
#                                       Best_Parameter
# 7                                                 {}
# 4  {'criterion': 'squared_error', 'n_estimators':...
# 6                                                 {}
# 8                                                 {}
# 3          {'n_neighbors': 5, 'weights': 'distance'}
# 0                                                 {}
# 1             {'ccp_alpha': 0.3, 'splitter': 'best'}
# 2                                                 {}
# 5                              {'n_estimators': 100}

# %%
gs.predict(X_test)
# Out:
# array([ 7071.8223, 27959.412 ,  4797.3604,  4694.573 ,  6955.9487,
#         4619.612 , 14609.803 ,  3589.247 ,  8308.842 ,  9392.468 ,
#        16256.973 , 41285.11  ,  9880.838 , 14173.17  ,  1645.1084,
#         6756.8022,  4648.266 ,  8920.644 , 29072.438 ,  8097.3394,
#        11795.326 , 12389.297 ,  4450.1987,  2529.0562,  3686.7524,
#        35089.22  , 10598.93  , 15537.951 ,   906.2946, 14400.95  ,
#         7531.4873,  5987.2363, 18045.584 , 23154.918 ,  1921.6895,
#        17896.537 ,  1219.6726,  6109.9185,  4606.786 , 11995.503 ,
#         5296.3413, 16035.52  ,  9805.357 ,  8042.152 ,  4790.806 ,
#        11645.717 ,  2389.9   , 12882.986 , 39622.176 , 12213.485 ,
#         5183.347 , 18887.725 ,  7036.068 , 19759.742 , 11190.99  ,
#         4826.901 , 13481.709 ,  7128.7983, 10481.605 ,  8996.639 ,
#        13509.694 , 12991.644 ,  1604.585 ,  9430.94  , 13956.635 ,
#        18437.904 ,  8172.7007,  9143.389 ,  9757.951 ,  9316.442 ,
#        33313.39  ,  5434.6797,  4752.952 ,  3885.6594, 19908.947 ,
#         4354.535 ,  7141.613 ,  6310.601 ,  9424.788 , 13622.637 ,
